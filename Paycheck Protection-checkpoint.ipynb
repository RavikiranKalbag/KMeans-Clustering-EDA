# %% [markdown]
# # Importing Datasets & Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv("public_150k_plus_220703.csv")

# %%
data.shape
# Out:
# (968532, 53)

# %% [markdown]
# ## Data Exploration

# %%
data.head()
# Out:
#    LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0  9547507704   05/01/2020            464              PPP
# 1  9777677704   05/01/2020            464              PPP
# 2  5791407702   05/01/2020           1013              PPP
# 3  6223567700   05/01/2020            920              PPP
# 4  9662437702   05/01/2020            101              PPP
#
#                BorrowerName        BorrowerAddress      BorrowerCity  \
# 0     SUMTER COATINGS, INC.  2410 Highway 15 South            Sumter
# 1     PLEASANT PLACES, INC.    7684 Southrail Road  North Charleston
# 2   BOYER CHILDREN'S CLINIC       1850 BOYER AVE E           SEATTLE
# 3  KIRTLEY CONSTRUCTION INC   1661 MARTIN RANCH RD    SAN BERNARDINO
# 4              AERO BOX LLC                    NaN               NaN
#
#   BorrowerState BorrowerZip LoanStatusDate  ...             BusinessType  \
# 0           NaN  29150-9662     12/18/2020  ...              Corporation
# ...

# %%
data.columns
# Out:
# Index(['LoanNumber', 'DateApproved', 'SBAOfficeCode', 'ProcessingMethod',
#        'BorrowerName', 'BorrowerAddress', 'BorrowerCity', 'BorrowerState',
#        'BorrowerZip', 'LoanStatusDate', 'LoanStatus', 'Term',
#        'SBAGuarantyPercentage', 'InitialApprovalAmount',
#        'CurrentApprovalAmount', 'UndisbursedAmount', 'FranchiseName',
#        'ServicingLenderLocationID', 'ServicingLenderName',
#        'ServicingLenderAddress', 'ServicingLenderCity', 'ServicingLenderState',
#        'ServicingLenderZip', 'RuralUrbanIndicator', 'HubzoneIndicator',
#        'LMIIndicator', 'BusinessAgeDescription', 'ProjectCity',
#        'ProjectCountyName', 'ProjectState', 'ProjectZip', 'CD', 'JobsReported',
#        'NAICSCode', 'Race', 'Ethnicity', 'UTILITIES_PROCEED',
#        'PAYROLL_PROCEED', 'MORTGAGE_INTEREST_PROCEED', 'RENT_PROCEED',
#        'REFINANCE_EIDL_PROCEED', 'HEALTH_CARE_PROCEED',
#        'DEBT_INTEREST_PROCEED', 'BusinessType', 'OriginatingLenderLocationID',
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 968532 entries, 0 to 968531
# Data columns (total 53 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   LoanNumber                   968532 non-null  int64
#  1   DateApproved                 968532 non-null  object
#  2   SBAOfficeCode                968532 non-null  int64
#  3   ProcessingMethod             968532 non-null  object
#  4   BorrowerName                 968528 non-null  object
#  5   BorrowerAddress              968518 non-null  object
#  6   BorrowerCity                 968520 non-null  object
#  7   BorrowerState                968519 non-null  object
#  8   BorrowerZip                  968519 non-null  object
#  9   LoanStatusDate               896656 non-null  object
#  10  LoanStatus                   968532 non-null  object
#  11  Term                         968532 non-null  int64
# ...

# %%
data.corr()
# Out:
#                              LoanNumber  SBAOfficeCode      Term  \
# LoanNumber                     1.000000      -0.006688 -0.066920
# SBAOfficeCode                 -0.006688       1.000000  0.006664
# Term                          -0.066920       0.006664  1.000000
# SBAGuarantyPercentage               NaN            NaN       NaN
# InitialApprovalAmount          0.008851      -0.006944 -0.069956
# CurrentApprovalAmount          0.009200      -0.006708 -0.068917
# UndisbursedAmount              0.000391      -0.002137 -0.000088
# ServicingLenderLocationID     -0.003103      -0.000015  0.065446
# JobsReported                  -0.010433      -0.001363 -0.078066
# NAICSCode                     -0.015697      -0.033382  0.058397
# UTILITIES_PROCEED              0.024819       0.004411 -0.233114
# PAYROLL_PROCEED                0.008990      -0.006766 -0.056568
# MORTGAGE_INTEREST_PROCEED     -0.000368       0.075352  0.015124
# ...

# %%
plt.figure(figsize = (14,8))
sns.heatmap(data.corr(), annot = True, cmap = 'coolwarm', linewidths = 0.5)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Missing Value Treatment

# %%
data.isna().sum()
# Out:
# LoanNumber                          0
# DateApproved                        0
# SBAOfficeCode                       0
# ProcessingMethod                    0
# BorrowerName                        4
# BorrowerAddress                    14
# BorrowerCity                       12
# BorrowerState                      13
# BorrowerZip                        13
# LoanStatusDate                  71876
# LoanStatus                          0
# Term                                0
# SBAGuarantyPercentage               0
# InitialApprovalAmount               0
# CurrentApprovalAmount               0
# UndisbursedAmount                  62
# FranchiseName                  933127
# ServicingLenderLocationID           0
# ServicingLenderName                 0
# ServicingLenderAddress              0
# ServicingLenderCity                 0
# ServicingLenderState                0
# ServicingLenderZip                  0
# RuralUrbanIndicator                 0
# HubzoneIndicator                    0
# ...

# %%
data.drop(['BorrowerName', 'BorrowerAddress'], axis = 1, inplace = True)

# %%
data['NonProfit'].value_counts()
# Out:
# Y    59339
# Name: NonProfit, dtype: int64

# %%
data['NonProfit'].fillna(value = 'N', inplace = True)
data['ForgivenessAmount'] = data['ForgivenessAmount'].fillna(data['ForgivenessAmount'].mean())

# %%
data['BusinessType'].fillna(data['BusinessType'].mode()[0], inplace = True)

# %%
data.isna().sum()
# Out:
# LoanNumber                          0
# DateApproved                        0
# SBAOfficeCode                       0
# ProcessingMethod                    0
# BorrowerCity                       12
# BorrowerState                      13
# BorrowerZip                        13
# LoanStatusDate                  71876
# LoanStatus                          0
# Term                                0
# SBAGuarantyPercentage               0
# InitialApprovalAmount               0
# CurrentApprovalAmount               0
# UndisbursedAmount                  62
# FranchiseName                  933127
# ServicingLenderLocationID           0
# ServicingLenderName                 0
# ServicingLenderAddress              0
# ServicingLenderCity                 0
# ServicingLenderState                0
# ServicingLenderZip                  0
# RuralUrbanIndicator                 0
# HubzoneIndicator                    0
# LMIIndicator                        0
# BusinessAgeDescription              1
# ...

# %%
print(data['DEBT_INTEREST_PROCEED'].value_counts())
print(data['HEALTH_CARE_PROCEED'].value_counts())
print(data['REFINANCE_EIDL_PROCEED'].value_counts())
print(data['RENT_PROCEED'].value_counts())
print(data['PAYROLL_PROCEED'].value_counts())
print(data['MORTGAGE_INTEREST_PROCEED'].value_counts())
print(data['UTILITIES_PROCEED'].value_counts())
# Out:
# 0.00         15402
# 10000.00       445
# 5000.00        424
# 2000.00        363
# 1000.00        303
#              ...
# 12023.00         1
# 223099.00        1
# 18469.00         1
# 3203.93          1
# 45531.00         1
# Name: DEBT_INTEREST_PROCEED, Length: 7884, dtype: int64
# 0.00         5761
# 20000.00      846
# 10000.00      837
# 15000.00      664
# 30000.00      610
#              ...
# 44724.00        1
# 47241.00        1
# 36063.00        1
# 111375.00       1
# 3414.27         1
# Name: HEALTH_CARE_PROCEED, Length: 27019, dtype: int64
# 0.00          21159
# 10000.00        763
# 150000.00        41
# 1.00             24
# 0.50             19
#               ...
# 2554086.00        1
# 137243.75         1
# 115350.00         1
# 104550.00         1
# 20266.00          1
# Name: REFINANCE_EIDL_PROCEED, Length: 734, dtype: int64
# 0.00        6047
# 20000.00    1909
# 10000.00    1588
# 30000.00    1559
# 15000.00    1089
#             ...
# 59681.00       1
# ...

# %%
data['DEBT_INTEREST_PROCEED'].fillna(0.00, inplace = True)
data['HEALTH_CARE_PROCEED'].fillna(0.00, inplace = True)
data['REFINANCE_EIDL_PROCEED'].fillna(0.00, inplace = True)
data['RENT_PROCEED'].fillna(0.00, inplace = True)
data['MORTGAGE_INTEREST_PROCEED'].fillna(0.00, inplace = True)
data['UTILITIES_PROCEED'].fillna(0.00, inplace = True)
data['PAYROLL_PROCEED'].fillna(150000.00, inplace = True)

# %%
data.isna().sum()
# Out:
# LoanNumber                          0
# DateApproved                        0
# SBAOfficeCode                       0
# ProcessingMethod                    0
# BorrowerCity                       12
# BorrowerState                      13
# BorrowerZip                        13
# LoanStatusDate                  71876
# LoanStatus                          0
# Term                                0
# SBAGuarantyPercentage               0
# InitialApprovalAmount               0
# CurrentApprovalAmount               0
# UndisbursedAmount                  62
# FranchiseName                  933127
# ServicingLenderLocationID           0
# ServicingLenderName                 0
# ServicingLenderAddress              0
# ServicingLenderCity                 0
# ServicingLenderState                0
# ServicingLenderZip                  0
# RuralUrbanIndicator                 0
# HubzoneIndicator                    0
# LMIIndicator                        0
# BusinessAgeDescription              1
# ...

# %%
data['BorrowerCity'].fillna(data['BorrowerCity'].mode()[0], inplace = True)
data['BorrowerState'].fillna(data['BorrowerState'].mode()[0], inplace = True)
data['BorrowerZip'].fillna(data['BorrowerZip'].mode()[0], inplace = True)
data['ProjectCity'].fillna(data['ProjectCity'].mode()[0], inplace = True)
data['ProjectCountyName'].fillna(data['ProjectCountyName'].mode()[0], inplace = True)
data['ProjectState'].fillna(data['ProjectState'].mode()[0], inplace = True)
data['ProjectZip'].fillna(data['ProjectZip'].mode()[0], inplace = True)

# %%
data.isna().sum()
# Out:
# LoanNumber                          0
# DateApproved                        0
# SBAOfficeCode                       0
# ProcessingMethod                    0
# BorrowerCity                        0
# BorrowerState                       0
# BorrowerZip                         0
# LoanStatusDate                  71876
# LoanStatus                          0
# Term                                0
# SBAGuarantyPercentage               0
# InitialApprovalAmount               0
# CurrentApprovalAmount               0
# UndisbursedAmount                  62
# FranchiseName                  933127
# ServicingLenderLocationID           0
# ServicingLenderName                 0
# ServicingLenderAddress              0
# ServicingLenderCity                 0
# ServicingLenderState                0
# ServicingLenderZip                  0
# RuralUrbanIndicator                 0
# HubzoneIndicator                    0
# LMIIndicator                        0
# BusinessAgeDescription              1
# ...

# %%
data.drop(["CD", "NAICSCode"], axis = 1, inplace = True)

# %%
data.drop(['ForgivenessDate', 'FranchiseName', 'LoanStatusDate'], axis = 1, inplace = True)

# %%
data.isna().sum()
# Out:
# LoanNumber                      0
# DateApproved                    0
# SBAOfficeCode                   0
# ProcessingMethod                0
# BorrowerCity                    0
# BorrowerState                   0
# BorrowerZip                     0
# LoanStatus                      0
# Term                            0
# SBAGuarantyPercentage           0
# InitialApprovalAmount           0
# CurrentApprovalAmount           0
# UndisbursedAmount              62
# ServicingLenderLocationID       0
# ServicingLenderName             0
# ServicingLenderAddress          0
# ServicingLenderCity             0
# ServicingLenderState            0
# ServicingLenderZip              0
# RuralUrbanIndicator             0
# HubzoneIndicator                0
# LMIIndicator                    0
# BusinessAgeDescription          1
# ProjectCity                     0
# ProjectCountyName               0
# ProjectState                    0
# ProjectZip                      0
# ...

# %%
data['JobsReported'].value_counts()
# Out:
# 15.0     29474
# 20.0     28621
# 18.0     26308
# 14.0     25594
# 16.0     25309
#          ...
# 474.0       31
# 457.0       31
# 451.0       29
# 446.0       27
# 0.0          4
# Name: JobsReported, Length: 501, dtype: int64

# %%
data['JobsReported'].fillna(15.0, inplace = True)
data['UndisbursedAmount'].fillna(data['UndisbursedAmount'].mean(), inplace = True)

# %%
data.isna().sum()
# Out:
# LoanNumber                     0
# DateApproved                   0
# SBAOfficeCode                  0
# ProcessingMethod               0
# BorrowerCity                   0
# BorrowerState                  0
# BorrowerZip                    0
# LoanStatus                     0
# Term                           0
# SBAGuarantyPercentage          0
# InitialApprovalAmount          0
# CurrentApprovalAmount          0
# UndisbursedAmount              0
# ServicingLenderLocationID      0
# ServicingLenderName            0
# ServicingLenderAddress         0
# ServicingLenderCity            0
# ServicingLenderState           0
# ServicingLenderZip             0
# RuralUrbanIndicator            0
# HubzoneIndicator               0
# LMIIndicator                   0
# BusinessAgeDescription         1
# ProjectCity                    0
# ProjectCountyName              0
# ProjectState                   0
# ProjectZip                     0
# JobsReported                   0
# ...

# %% [markdown]
# - All missing values are being replaced successfully.

# %% [markdown]
# # Exploratory Data Analysis

# %%
data.columns
# Out:
# Index(['LoanNumber', 'DateApproved', 'SBAOfficeCode', 'ProcessingMethod',
#        'BorrowerCity', 'BorrowerState', 'BorrowerZip', 'LoanStatus', 'Term',
#        'SBAGuarantyPercentage', 'InitialApprovalAmount',
#        'CurrentApprovalAmount', 'UndisbursedAmount',
#        'ServicingLenderLocationID', 'ServicingLenderName',
#        'ServicingLenderAddress', 'ServicingLenderCity', 'ServicingLenderState',
#        'ServicingLenderZip', 'RuralUrbanIndicator', 'HubzoneIndicator',
#        'LMIIndicator', 'BusinessAgeDescription', 'ProjectCity',
#        'ProjectCountyName', 'ProjectState', 'ProjectZip', 'JobsReported',
#        'Race', 'Ethnicity', 'UTILITIES_PROCEED', 'PAYROLL_PROCEED',
#        'MORTGAGE_INTEREST_PROCEED', 'RENT_PROCEED', 'REFINANCE_EIDL_PROCEED',
#        'HEALTH_CARE_PROCEED', 'DEBT_INTEREST_PROCEED', 'BusinessType',
#        'OriginatingLenderLocationID', 'OriginatingLender',
#        'OriginatingLenderCity', 'OriginatingLenderState', 'Gender', 'Veteran',
# ...

# %% [markdown]
# ## Ethnicity

# %%
plt.figure(figsize = (12,8))
sns.countplot(x = 'Ethnicity', hue = 'Gender', data = data)
plt.show()

# %% [markdown]
# - Most of the males are identified as Not Hispanic or Latino.
#
# - Most of the Unanswered Gender Identities have also no stated their Ethnicity Identity.

# %% [markdown]
# ## Business Age

# %%
plt.figure(figsize = (12,8))
sns.set_style('whitegrid')
sns.countplot(x = 'BusinessAgeDescription', hue = 'Gender', data = data)
plt.tight_layout()

# %% [markdown]
# - Majority of the unanswered & male group people have their existing business for more than 2 years.

# %%
data.columns
# Out:
# Index(['LoanNumber', 'DateApproved', 'SBAOfficeCode', 'ProcessingMethod',
#        'BorrowerCity', 'BorrowerState', 'BorrowerZip', 'LoanStatus', 'Term',
#        'SBAGuarantyPercentage', 'InitialApprovalAmount',
#        'CurrentApprovalAmount', 'UndisbursedAmount',
#        'ServicingLenderLocationID', 'ServicingLenderName',
#        'ServicingLenderAddress', 'ServicingLenderCity', 'ServicingLenderState',
#        'ServicingLenderZip', 'RuralUrbanIndicator', 'HubzoneIndicator',
#        'LMIIndicator', 'BusinessAgeDescription', 'ProjectCity',
#        'ProjectCountyName', 'ProjectState', 'ProjectZip', 'JobsReported',
#        'Race', 'Ethnicity', 'UTILITIES_PROCEED', 'PAYROLL_PROCEED',
#        'MORTGAGE_INTEREST_PROCEED', 'RENT_PROCEED', 'REFINANCE_EIDL_PROCEED',
#        'HEALTH_CARE_PROCEED', 'DEBT_INTEREST_PROCEED', 'BusinessType',
#        'OriginatingLenderLocationID', 'OriginatingLender',
#        'OriginatingLenderCity', 'OriginatingLenderState', 'Gender', 'Veteran',
# ...

# %%
data['BusinessType'].value_counts()
# Out:
# Corporation                            419075
# Limited  Liability Company(LLC)        261285
# Subchapter S Corporation               174830
# Non-Profit Organization                 55899
# Partnership                             18168
# Limited Liability Partnership           12729
# Sole Proprietorship                     12292
# Professional Association                 6279
# Cooperative                              2436
# 501(c)3 – Non Profit                     1766
# Non-Profit Childcare Center               900
# 501(c)6 – Non Profit Membership           762
# Employee Stock Ownership Plan(ESOP)       641
# Self-Employed Individuals                 495
# Trust                                     398
# Housing Co-op                             152
# Joint Venture                             125
# Independent Contractors                   112
# Single Member LLC                          77
# Tribal Concerns                            64
# ...

# %%
data['JobsReported']
# Out:
# 0         62.0
# 1         73.0
# 2         75.0
# 3         21.0
# 4         25.0
#           ...
# 968527    15.0
# 968528    42.0
# 968529     5.0
# 968530     7.0
# 968531    11.0
# Name: JobsReported, Length: 968532, dtype: float64

# %% [markdown]
# ## Number of jobs reported by different business types

# %%
table = pd.pivot_table( data=data, 
                    #    index=['Gender'], 
                        columns=['BusinessType'], 
                        values='JobsReported',
                        aggfunc='sum')

# %%
plt.figure(figsize = (12,8))
sns.barplot(x = 'BusinessType', y = 'JobsReported', data = data)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - Non Profit, Tribal Concerns & ESOP are highly counted Business Types.
